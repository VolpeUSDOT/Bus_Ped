# %% [markdown]
# create a driver_schedule table, and
# for each month, and for each route, add all records to that single table
#
# we may care to sort the records before adding to the database table
#
# first, we need to know if it is safe to use vehicle_assignment_id as the
# primary key for driver schedule records, so we test for uniqueness across all
# data files: for each VehiclesThatRanRoute file across all routes and months,
# read vehicle_assignment_id values into an array, count the unique array
# entries and compare for equality with the array length.

# %%
import numpy as np
from os import path, walk
import pandas as pd
from sqlalchemy import create_engine

# Search over .zip files in LADOT Synchromatics data
project_root_dir = r'\\vntscex.local\DFS\3BC-Share$_Mobileye_Data\Data\Data Integration - All Months' 
data_root_dir = path.join(project_root_dir, 'data_sources')

vehicle_assignment_data = []

# %%
for dir, subdirs, files in walk(data_root_dir):
    print(files)
# Out:
# []
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_100118_to_103118.txt', '296_296DASHB_VehiclesThatRanRoute_100118_to_103118.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_100118_to_103118.txt', '297_297DASHE_VehiclesThatRanRoute_100118_to_103118.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_100118_to_103118.txt', '298_298DASHF_VehiclesThatRanRoute_100118_to_103118.txt']
# ['9212_9212DASHD_RouteAndStops.txt', '9212_9212DASHD_StopTimes_100118_to_103118.txt', '9212_9212DASHD_VehiclesThatRanRoute_100118_to_103118.txt']
# ['9960_9960DASHA_StopTimes_100118_to_103118.txt', '9960_9960DASHA_VehiclesThatRanRoute_100118_to_103118.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_090118_to_093018.txt', '296_296DASHB_VehiclesThatRanRoute_090118_to_093018.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_090118_to_093018.txt', '297_297DASHE_VehiclesThatRanRoute_090118_to_093018.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_090118_to_093018.txt', '298_298DASHF_VehiclesThatRanRoute_090118_to_093018.txt']
# ['9212_9212DASHD_RouteAndStops.txt', '9212_9212DASHD_StopTimes_090118_to_093018.txt', '9212_9212DASHD_VehiclesThatRanRoute_090118_to_093018.txt']
# ['9270_9270DASHAended92_RouteAndStops.txt', '9270_9270DASHAended92_StopTimes_090118_to_093018.txt', '9270_9270DASHAended92_VehiclesThatRanRoute_090118_to_093018.txt']
# ['9960_9960DASHA_StopTimes_090118_to_093018.txt', '9960_9960DASHA_VehiclesThatRanRoute_090118_to_093018.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_080118_to_083118.txt', '296_296DASHB_VehiclesThatRanRoute_080118_to_083118.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_080118_to_083118.txt', '297_297DASHE_VehiclesThatRanRoute_080118_to_083118.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_080118_to_083118.txt', '298_298DASHF_VehiclesThatRanRoute_080118_to_083118.txt']
# ['9212_9212DASHD_RouteAndStops.txt', '9212_9212DASHD_StopTimes_080118_to_083118.txt', '9212_9212DASHD_VehiclesThatRanRoute_080118_to_083118.txt']
# ['9270_9270DASHAended92_RouteAndStops.txt', '9270_9270DASHAended92_StopTimes_080118_to_083118.txt', '9270_9270DASHAended92_VehiclesThatRanRoute_080118_to_083118.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_070118_to_073118.txt', '296_296DASHB_VehiclesThatRanRoute_070118_to_073118.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_070118_to_073118.txt', '297_297DASHE_VehiclesThatRanRoute_070118_to_073118.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_070118_to_073118.txt', '298_298DASHF_VehiclesThatRanRoute_070118_to_073118.txt']
# ['8435_8435DASHAended71_RouteAndStops.txt', '8435_8435DASHAended71_StopTimes_070118_to_073118.txt', '8435_8435DASHAended71_VehiclesThatRanRoute_070118_to_073118.txt']
# ['9212_9212DASHD_RouteAndStops.txt', '9212_9212DASHD_StopTimes_070118_to_073118.txt', '9212_9212DASHD_VehiclesThatRanRoute_070118_to_073118.txt']
# ['9270_9270DASHAended92_RouteAndStops.txt', '9270_9270DASHAended92_StopTimes_070118_to_073118.txt', '9270_9270DASHAended92_VehiclesThatRanRoute_070118_to_073118.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_060118_to_063018.txt', '296_296DASHB_VehiclesThatRanRoute_060118_to_063018.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_060118_to_063018.txt', '297_297DASHE_VehiclesThatRanRoute_060118_to_063018.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_060118_to_063018.txt', '298_298DASHF_VehiclesThatRanRoute_060118_to_063018.txt']
# ['408_408DASHDended627_RouteAndStops.txt', '408_408DASHDended627_StopTimes_060118_to_063018.txt', '408_408DASHDended627_VehiclesThatRanRoute_060118_to_063018.txt']
# ['8435_8435DASHAended71_RouteAndStops.txt', '8435_8435DASHAended71_StopTimes_060118_to_063018.txt', '8435_8435DASHAended71_VehiclesThatRanRoute_060118_to_063018.txt']
# ['9212_9212DASHD_RouteAndStops.txt', '9212_9212DASHD_StopTimes_060118_to_063018.txt', '9212_9212DASHD_VehiclesThatRanRoute_060118_to_063018.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_050118_to_053118.txt', '296_296DASHB_VehiclesThatRanRoute_050118_to_053118.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_050118_to_053118.txt', '297_297DASHE_VehiclesThatRanRoute_050118_to_053118.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_050118_to_053118.txt', '298_298DASHF_VehiclesThatRanRoute_050118_to_053118.txt']
# ['408_408DASHDended627_RouteAndStops.txt', '408_408DASHDended627_StopTimes_050118_to_053118.txt', '408_408DASHDended627_VehiclesThatRanRoute_050118_to_053118.txt']
# ['8435_8435DASHAended71_RouteAndStops.txt', '8435_8435DASHAended71_StopTimes_050118_to_053118.txt', '8435_8435DASHAended71_VehiclesThatRanRoute_050118_to_053118.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_040118_to_043018.txt', '296_296DASHB_VehiclesThatRanRoute_040118_to_043018.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_040118_to_043018.txt', '297_297DASHE_VehiclesThatRanRoute_040118_to_043018.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_040118_to_043018.txt', '298_298DASHF_VehiclesThatRanRoute_040118_to_043018.txt']
# ['408_408DASHDended627_RouteAndStops.txt', '408_408DASHDended627_StopTimes_040118_to_043018.txt', '408_408DASHDended627_VehiclesThatRanRoute_040118_to_043018.txt']
# ['8435_8435DASHAended71_RouteAndStops.txt', '8435_8435DASHAended71_StopTimes_040118_to_043018.txt', '8435_8435DASHAended71_VehiclesThatRanRoute_040118_to_043018.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_030118_to_033118.txt', '296_296DASHB_VehiclesThatRanRoute_030118_to_033118.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_030118_to_033118.txt', '297_297DASHE_VehiclesThatRanRoute_030118_to_033118.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_030118_to_033118.txt', '298_298DASHF_VehiclesThatRanRoute_030118_to_033118.txt']
# ['408_408DASHDended627_RouteAndStops.txt', '408_408DASHDended627_StopTimes_030118_to_033118.txt', '408_408DASHDended627_VehiclesThatRanRoute_030118_to_033118.txt']
# ['8435_8435DASHAended71_RouteAndStops.txt', '8435_8435DASHAended71_StopTimes_030118_to_033118.txt', '8435_8435DASHAended71_VehiclesThatRanRoute_030118_to_033118.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_020118_to_022818.txt', '296_296DASHB_VehiclesThatRanRoute_020118_to_022818.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_020118_to_022818.txt', '297_297DASHE_VehiclesThatRanRoute_020118_to_022818.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_020118_to_022818.txt', '298_298DASHF_VehiclesThatRanRoute_020118_to_022818.txt']
# ['408_408DASHDended627_RouteAndStops.txt', '408_408DASHDended627_StopTimes_020118_to_022818.txt', '408_408DASHDended627_VehiclesThatRanRoute_020118_to_022818.txt']
# ['409_409DASHA_RouteAndStops.txt', '409_409DASHA_StopTimes_020118_to_022818.txt', '409_409DASHA_VehiclesThatRanRoute_020118_to_022818.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_010118_to_013118.txt', '296_296DASHB_VehiclesThatRanRoute_010118_to_013118.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_010118_to_013118.txt', '297_297DASHE_VehiclesThatRanRoute_010118_to_013118.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_010118_to_013118.txt', '298_298DASHF_VehiclesThatRanRoute_010118_to_013118.txt']
# ['408_408DASHDended627_RouteAndStops.txt', '408_408DASHDended627_StopTimes_010118_to_013118.txt', '408_408DASHDended627_VehiclesThatRanRoute_010118_to_013118.txt']
# ['409_409DASHA_RouteAndStops.txt', '409_409DASHA_StopTimes_010118_to_013118.txt', '409_409DASHA_VehiclesThatRanRoute_010118_to_013118.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_110118_to_113018.txt', '296_296DASHB_VehiclesThatRanRoute_110118_to_113018.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_110118_to_113018.txt', '297_297DASHE_VehiclesThatRanRoute_110118_to_113018.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_110118_to_113018.txt', '298_298DASHF_VehiclesThatRanRoute_110118_to_113018.txt']
# ['8435_8435DASHAended71_RouteAndStops.txt']
# ['8758_8758DASHAEffecti_RouteAndStops.txt']
# ['9212_9212DASHD_RouteAndStops.txt', '9212_9212DASHD_StopTimes_110118_to_113018.txt', '9212_9212DASHD_VehiclesThatRanRoute_110118_to_113018.txt']
# ['9270_9270DASHAended92_RouteAndStops.txt']
# ['9736_9736DASHDended62_RouteAndStops.txt']
# ['9960_9960DASHA_StopTimes_110118_to_113018.txt', '9960_9960DASHA_VehiclesThatRanRoute_110118_to_113018.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_120118_to_123118.txt', '296_296DASHB_VehiclesThatRanRoute_120118_to_123118.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_120118_to_123118.txt', '297_297DASHE_VehiclesThatRanRoute_120118_to_123118.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_120118_to_123118.txt', '298_298DASHF_VehiclesThatRanRoute_120118_to_123118.txt']
# ['408_408DASHDended627_RouteAndStops.txt']
# ['409_409DASHA_RouteAndStops.txt']
# ['7690_7690DASHFEffecti_RouteAndStops.txt']
# ['8435_8435DASHAended71_RouteAndStops.txt']
# ['8758_8758DASHAEffecti_RouteAndStops.txt']
# ['9212_9212DASHD_RouteAndStops.txt', '9212_9212DASHD_StopTimes_120118_to_123118.txt', '9212_9212DASHD_VehiclesThatRanRoute_120118_to_123118.txt']
# ['9270_9270DASHAended92_RouteAndStops.txt']
# ['9736_9736DASHDended62_RouteAndStops.txt']
# ['9960_9960DASHA_StopTimes_120118_to_123118.txt', '9960_9960DASHA_VehiclesThatRanRoute_120118_to_123118.txt']
# []
# ['296_296DASHB_RouteAndStops.txt', '296_296DASHB_StopTimes_123118_to_010119.txt', '296_296DASHB_VehiclesThatRanRoute_123118_to_010119.txt']
# ['297_297DASHE_RouteAndStops.txt', '297_297DASHE_StopTimes_123118_to_010119.txt', '297_297DASHE_VehiclesThatRanRoute_123118_to_010119.txt']
# ['298_298DASHF_RouteAndStops.txt', '298_298DASHF_StopTimes_123118_to_010119.txt', '298_298DASHF_VehiclesThatRanRoute_123118_to_010119.txt']
# ['408_408DASHDended627_RouteAndStops.txt']
# ['409_409DASHA_RouteAndStops.txt']
# ['7690_7690DASHFEffecti_RouteAndStops.txt']
# ['8435_8435DASHAended71_RouteAndStops.txt']
# ['8758_8758DASHAEffecti_RouteAndStops.txt']
# ['9212_9212DASHD_RouteAndStops.txt', '9212_9212DASHD_StopTimes_123118_to_010119.txt', '9212_9212DASHD_VehiclesThatRanRoute_123118_to_010119.txt']
# ['9270_9270DASHAended92_RouteAndStops.txt']
# ['9736_9736DASHDended62_RouteAndStops.txt']
# ['9960_9960DASHA_StopTimes_123118_to_010119.txt', '9960_9960DASHA_VehiclesThatRanRoute_123118_to_010119.txt']

# %%
for dir, subdirs, files in walk(data_root_dir):
  # we assume that files only exist at the nodes
  if len(files) > 0:
    # we assume that only one driver schedule file exists in the current dir
    try:
      file_name_indices = [
        file.find('_VehiclesThatRanRoute_') >= 0 for file in files]

      file_name_index = file_name_indices.index(True)
      file_name = files[file_name_index]
      file_path = path.join(dir, file_name)

      # forget using np.unicode_ for strings since pandas treats them as objects
      # we can specify the data type since none of the values are null
      df = pd.read_table(
        file_path, usecols=[0, 1, 2, 3, 5, 6, 11, 12, 13, 14],
        header=None, skiprows=[0], parse_dates=['start_time', 'end_time'],
        names=['vehicle_assignment_id', 'vehicle_id', 'route_id', 'driver_id',
               'start_time', 'end_time', 'bus_number', 'first_name',
               'last_name', 'badge_number'],
        dtype={'vehicle_assignment_id': np.uint64, 'vehicle_id': np.uint32,
               'route_id': np.uint32, 'driver_id': np.uint32,
               'start_time': object, 'end_time': object,
               'bus_number': np.uint32, 'first_name': object,
               'last_name': object, 'badge_number': np.uint32})

      print(df.head(2))
      print(df.dtypes)

      vehicle_assignment_data.append(df)
    except Exception as e:
      print('Driver schedule file not found in {}'.format(dir))
      print(e)
      continue

# %%
vehicle_assignment_data = pd.concat(
  vehicle_assignment_data, ignore_index=True, verify_integrity=True)

# records of runs that span two days may appear once for each day depending on
# how the Excel exports were preformed, and should be dropped
vehicle_assignment_data.drop_duplicates(inplace=True)

# we temporarily also drop records with missing values to prove our concept.
# Key attributes that require values include 1) vehicle_assessment_id,
# 2) vehicle_id, 3) BusNumber, 4) driver_id (at least for longitudinal),
# 5) start_time, and 6) end_time.
# TODO: Infer missing values where possible using warning and route data
key_column_names = ['vehicle_assignment_id', 'vehicle_id', 'bus_number',
                    'driver_id', 'start_time', 'end_time']

vehicle_assignment_data.dropna(subset=key_column_names, inplace=True)

# we make no assumption about the order in which source xlsx files are input
vehicle_assignment_data.sort_values(['start_time', 'end_time'], inplace=True)

# after removing duplicate records, vehicle_assignment_ids will be unique and
# can be used as the primary key of the vehicle_assignment table. Because we
# don't yet know how this results in a SQLite PK, just reset the indices for now
# vehicle_assignment_data.set_index('vehicle_assignment_id', inplace=True)
vehicle_assignment_data.set_index(
  pd.RangeIndex(vehicle_assignment_data.shape[0]), inplace=True)

print(vehicle_assignment_data.describe())
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-ddc34761818d> in <module>
#       1 vehicle_assignment_data = pd.concat(
# ----> 2   vehicle_assignment_data, ignore_index=True, verify_integrity=True)
#       3
#       4 # records of runs that span two days may appear once for each day depending on
#       5 # how the Excel exports were preformed, and should be dropped
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     257
#     258         if len(objs) == 0:
# --> 259             raise ValueError('No objects to concatenate')
#     260
#     261         if keys is None:
#
# ValueError: No objects to concatenate

# %%
# db_path = 'sqlite:///ituran_synchromatics_data.sqlite'
db_path = 'sqlite:///' + path.join(project_root_dir, 'ituran_synchromatics_data.sqlite')

db = create_engine(db_path)

# poor performance has been observed when adding more than one million records
# at a time
vehicle_assignment_data.to_sql(
  'vehicle_assignment', db, if_exists='replace', chunksize=1000000, index=False)
